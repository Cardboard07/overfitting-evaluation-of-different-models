# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## loading dataset and quick glances

# %%
tot_data=pd.read_csv(r"C:\Users\hrish\Projects\ML_projects_to_learn\customer_churn\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %% [markdown]
# ## splitting the data

# %%
from sklearn.model_selection import train_test_split
y=tot_data[['Churn','customerID']]
X=tot_data.drop(columns=['Churn'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y['Churn'], random_state=42)

# %%
data=X_train.copy()

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6661  3704-IEAXF  Female              0     Yes        Yes      72
# 4811  5175-AOBHI  Female              0      No         No       4
# 2193  6922-NCEDI    Male              0      No        Yes      56
# 1904  3143-ILDAL    Male              0      No         No      56
# 6667  0872-NXJYS  Female              0      No         No       9
# ...          ...     ...            ...     ...        ...     ...
# 4250  0565-JUPYD    Male              0      No         No      63
# 1488  8695-WDYEA    Male              0      No         No       1
# 6303  6308-CQRBU  Female              0     Yes         No      71
# 2710  3594-BDSOA  Female              0     Yes         No      24
# 5639  6490-FGZAT    Male              0      No         No       6
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 6661           No  No phone service             DSL                   No
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5282 entries, 6661 to 5639
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5282 non-null   str
#  1   gender            5282 non-null   str
#  2   SeniorCitizen     5282 non-null   int64
#  3   Partner           5282 non-null   str
#  4   Dependents        5282 non-null   str
#  5   tenure            5282 non-null   int64
#  6   PhoneService      5282 non-null   str
#  7   MultipleLines     5282 non-null   str
#  8   InternetService   5282 non-null   str
#  9   OnlineSecurity    5282 non-null   str
#  10  OnlineBackup      5282 non-null   str
#  11  DeviceProtection  5282 non-null   str
#  12  TechSupport       5282 non-null   str
#  13  StreamingTV       5282 non-null   str
#  14  StreamingMovies   5282 non-null   str
#  15  Contract          5282 non-null   str
#  16  PaperlessBilling  5282 non-null   str
# ...

# %% [raw]
# need to transform a lot of data before I can use describe
# there are no nulls at all
# need to transform the data
# then do the rest of the basic glances

# %%
for col in data.columns:
    if(len(data[col].unique())<5):
        print(f"{col}: {data[col].unique()}")
# Out:
# gender: <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# SeniorCitizen: [0 1]
# Partner: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# Dependents: <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# PhoneService: <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# MultipleLines: <StringArray>
# ['No phone service', 'No', 'Yes']
# Length: 3, dtype: str
# InternetService: <StringArray>
# ['DSL', 'No', 'Fiber optic']
# Length: 3, dtype: str
# OnlineSecurity: <StringArray>
# ['No', 'No internet service', 'Yes']
# Length: 3, dtype: str
# OnlineBackup: <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# DeviceProtection: <StringArray>
# ['No', 'No internet service', 'Yes']
# Length: 3, dtype: str
# TechSupport: <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# StreamingTV: <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# StreamingMovies: <StringArray>
# ...

# %% [raw]
# ok here now I have multiple columns that have yes,no,no service
# i also have a column where i have service type and no
# so they are all related
# my idea is to one hot encode service col
# i will get typ1, typ2 and no_service, all other columns I will consider both no service and no as 0

# %% [raw]
# data['gender'] = (data['gender'] == 'Male').astype(int)

# %% [raw]
# data.columns[9:15]
# for x in data.columns[9:15]:
#     data[x]=(data[x]=='Yes').astype(int)
# for x in data.columns[3:5]:
#     data[x]=(data[x]=='Yes').astype(int)
# #phone service
# data['PhoneService'] = (data['PhoneService'] == 'Yes').astype(int)
# data['MultipleLines'] = (data['MultipleLines'] == 'Yes').astype(int)
# data['PaperlessBilling'] = (data['PaperlessBilling'] == 'Yes').astype(int)

# %% [raw]
# from sklearn.preprocessing import OneHotEncoder
# enc = OneHotEncoder(sparse_output=False)
# encoded = enc.fit_transform(data[['InternetService']])
# encoded_df = pd.DataFrame(encoded,columns=enc.get_feature_names_out(['InternetService']),index=data.index)
# data = pd.concat([data.drop(columns=['InternetService']), encoded_df], axis=1)

# %% [raw]
# note_to_self: sparse_output is to get dense numpy array instead of some matrix

# %% [raw]
# need to try different methods to deal with contract
# i am going to one hot encode it as a baseline

# %% [raw]
# encoded = enc.fit_transform(data[['Contract']])
# encoded_df = pd.DataFrame(encoded,columns=enc.get_feature_names_out(['Contract']),index=data.index)
# data = pd.concat([data.drop(columns=['Contract']), encoded_df], axis=1)

# %% [raw]
# i am going to one hot payment methods as a baseline

# %% [raw]
# encoded = enc.fit_transform(data[['PaymentMethod']])
# encoded_df = pd.DataFrame(encoded,columns=enc.get_feature_names_out(['PaymentMethod']),index=data.index)
# data = pd.concat([data.drop(columns=['PaymentMethod']), encoded_df], axis=1)

# %%
(data['TotalCharges']==' ').sum()
# Out:
# np.int64(8)

# %%
data[data['TotalCharges']==' '][['MonthlyCharges','tenure']]
# Out:
#       MonthlyCharges  tenure
# 6670           73.35       0
# 3826           25.35       0
# 4380           20.00       0
# 488            52.55       0
# 1082           25.75       0
# 1340           56.05       0
# 6754           61.90       0
# 3331           19.85       0

# %% [raw]
# (data['tenure']==0).sum()

# %% [raw]
# so basically I tried converting total charges to float
# but it had ' '
# so I tried to see if I could calculate it using tenure and monthly
# there are 11 of those
# then i realised those 11 have tenure 0
# so setting those to 0

# %% [raw]
# data['TotalCharges']=data['TotalCharges'].replace(' ',0)

# %% [raw]
# data['TotalCharges'] = data['TotalCharges'].astype(float)

# %% [markdown]
# ### doing the above using transformers and pipelines

# %% [raw]
# need a function transformer to convert yes and no columns to 1,0
# need to one hot encode other stuff
# need an other function transformer for total_charges
# will wrap all of these in a column transormer

# %%
def true_conv(n):
    return (n=='Yes').astype(int)
def clean_total_charges(X):
    return X.replace(' ', 0).astype(float)
def gen_func(n):
    return (n=='Male').astype(int)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
enc = OneHotEncoder(sparse_output=False)

# %%
bin_at=list(data.columns[9:15])+list(data.columns[3:5])+['PhoneService','MultipleLines','PaperlessBilling']
ohe_at=['InternetService','Contract','PaymentMethod']
yes_no_transformer = FunctionTransformer(true_conv, feature_names_out='one-to-one')
charges_transformer = FunctionTransformer(clean_total_charges, feature_names_out='one-to-one')
gender_transformer = FunctionTransformer(gen_func, feature_names_out='one-to-one')
preprocessing = ColumnTransformer([("yes_to_1", yes_no_transformer, bin_at),("ohe", enc, ohe_at),('tot_char',charges_transformer,['TotalCharges']),('ohe_gen',gender_transformer,['gender'])],remainder='passthrough',verbose_feature_names_out=False)
preprocessing.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('yes_to_1',
#                                  FunctionTransformer(feature_names_out='one-to-one',
#                                                      func=<function true_conv at 0x00000234D4F67B00>),
#                                  ['OnlineSecurity', 'OnlineBackup',
#                                   'DeviceProtection', 'TechSupport',
#                                   'StreamingTV', 'StreamingMovies', 'Partner',
#                                   'Dependents', 'PhoneService', 'MultipleLines',
#                                   'PaperlessBilling']),
#                                 ('ohe', OneHo...utput=False),
#                                  ['InternetService', 'Contract',
#                                   'PaymentMethod']),
#                                 ('tot_char',
#                                  FunctionTransformer(feature_names_out='one-to-one',
# ...

# %%
processed_data = preprocessing.fit_transform(data)

# %%
y_train['Churn'] = (y_train['Churn'] == 'Yes').astype(int)

# %%
processed_data
# Out:
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 6661               0             1                 0            1
# 4811               0             0                 0            0
# 2193               0             0                 0            0
# 1904               0             1                 0            1
# 6667               0             0                 0            0
# ...              ...           ...               ...          ...
# 4250               1             1                 1            1
# 1488               1             0                 0            0
# 6303               0             1                 1            1
# 2710               0             0                 0            0
# 5639               0             0                 0            0
#
#       StreamingTV  StreamingMovies  Partner  Dependents  PhoneService  \
# 6661            1                1        1           1             0
# ...

# %%
processed_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5282 entries, 6661 to 5639
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   OnlineSecurity                           5282 non-null   int64
#  1   OnlineBackup                             5282 non-null   int64
#  2   DeviceProtection                         5282 non-null   int64
#  3   TechSupport                              5282 non-null   int64
#  4   StreamingTV                              5282 non-null   int64
#  5   StreamingMovies                          5282 non-null   int64
#  6   Partner                                  5282 non-null   int64
#  7   Dependents                               5282 non-null   int64
#  8   PhoneService                             5282 non-null   int64
#  9   MultipleLines                            5282 non-null   int64
# ...

# %%
processed_data[['tenure','MonthlyCharges','TotalCharges',]].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  5282.000000     5282.000000   5282.000000
# mean     32.362931       64.856626   2292.083538
# std      24.627623       30.171934   2285.168876
# min       0.000000       18.400000      0.000000
# 25%       9.000000       35.450000    391.062500
# 50%      29.000000       70.500000   1385.300000
# 75%      55.750000       89.987500   3841.637500
# max      72.000000      118.750000   8684.800000

# %%
y_train['Churn'].value_counts()
# Out:
# Churn
# 0    3880
# 1    1402
# Name: count, dtype: int64

# %% [markdown]
# ## Data processing and data visualisation

# %%
processed_data.hist(bins=50,figsize=(12,8))
plt.show()

# %%
data_vis=pd.merge(processed_data, y_train, on="customerID")

# %%
one_hot_cols = list(data_vis.columns[0:21])+['gender','SeniorCitizen']
df_y1 = data_vis[data_vis['Churn'] == 1]
counts = {}
for col in one_hot_cols:
    counts[col] = df_y1[col].value_counts().reindex([1,0], fill_value=0)
counts_df = pd.DataFrame(counts).T.reset_index()
counts_df.columns = ['Feature', 'Count_1', 'Count_0']

plot_df = counts_df.melt(id_vars='Feature', value_vars=['Count_1','Count_0'],
                         var_name='Value', value_name='Count')

plt.figure(figsize=(40,20))
sns.barplot(x='Feature', y='Count', hue='Value', data=plot_df, palette='Set2')
plt.title("Counts of 0s and 1s in One-Hot Features (y=1)")
plt.show()

# %%
one_hot_cols = list(data_vis.columns[0:21])+['gender','SeniorCitizen']
df_y1 = data_vis[data_vis['Churn'] == 0]
counts = {}
for col in one_hot_cols:
    counts[col] = df_y1[col].value_counts().reindex([1,0], fill_value=0)
counts_df = pd.DataFrame(counts).T.reset_index()
counts_df.columns = ['Feature', 'Count_1', 'Count_0']

plot_df = counts_df.melt(id_vars='Feature', value_vars=['Count_1','Count_0'],
                         var_name='Value', value_name='Count')

plt.figure(figsize=(40,20))
sns.barplot(x='Feature', y='Count', hue='Value', data=plot_df, palette='Set2')
plt.title("Counts of 0s and 1s in One-Hot Features (y=0)")
plt.show()

# %%
corr = data_vis.drop(columns="customerID").corr()[['Churn']] 
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))

# Histogram for churn = 0
plt.hist(data_vis[data_vis['Churn']==0]['TotalCharges'], 
         bins=30, alpha=0.6, label='Churn = 0')

# Histogram for churn = 1
plt.hist(data_vis[data_vis['Churn']==1]['TotalCharges'], 
         bins=30, alpha=0.6, label='Churn = 1')

plt.xlabel('TotalCharges')
plt.ylabel('Count')
plt.title('Distribution of TotalCharges by Churn')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

# Histogram for churn = 0
plt.hist(data_vis[data_vis['Churn']==0]['MonthlyCharges'], 
         bins=30, alpha=0.6, label='Churn = 0')

# Histogram for churn = 1
plt.hist(data_vis[data_vis['Churn']==1]['MonthlyCharges'], 
         bins=30, alpha=0.6, label='Churn = 1')

plt.xlabel('MonthlyCharges')
plt.ylabel('Count')
plt.title('Distribution of TotalCharges by Churn')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

# Histogram for churn = 0
plt.hist(data_vis[data_vis['Churn']==0]['tenure'], 
         bins=30, alpha=0.6, label='Churn = 0')

# Histogram for churn = 1
plt.hist(data_vis[data_vis['Churn']==1]['tenure'], 
         bins=30, alpha=0.6, label='Churn = 1')

plt.xlabel('Tenure')
plt.ylabel('Count')
plt.title('Distribution of Tenure by Churn')
plt.legend()
plt.show()

# %% [markdown]
# ## feature transformation and feature scaling

# %%
from sklearn.preprocessing import FunctionTransformer
log_trans = FunctionTransformer(np.log1p, feature_names_out='one-to-one')

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted,validate_data

class MedianRBFTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, gamma=0.1):
        self.gamma = gamma

    def fit(self, X, y=None):
        # Validates input, converts to array, and handles feature_names_in_
        X = validate_data(self, X=X, reset=True)
        
        # Calculate medians across rows (axis=0)
        # Shape becomes (n_features,) which broadcasts perfectly over X
        self.medians_ = np.median(X, axis=0) 
        return self

    def transform(self, X):
        # Ensure fit has been called
        check_is_fitted(self, 'medians_')
        
        # Validate input without overwriting fit attributes
        X = validate_data(self, X=X, reset=True)

        # Fully vectorized RBF calculation (No for-loops)
        transformed = np.exp(-self.gamma * (X - self.medians_) ** 2)
        
        return transformed

    def get_feature_names_out(self, input_features=None):
        """Allows sklearn to automatically format pandas outputs."""
        if input_features is None:
            input_features = getattr(self, "feature_names_in_", None)
        
        # Fallback if numpy array was passed without feature names
        if input_features is None:
            input_features = [f"x{i}" for i in range(self.medians_.shape[0])]
            
        return np.array([f"rbf_{name}" for name in input_features])

# %%
rb_col=['MonthlyCharges','tenure']
ftr_trs = ColumnTransformer([("rbf_kernel", MedianRBFTransformer(gamma=0.1), rb_col),("log", log_trans, ['TotalCharges'])],remainder='passthrough',verbose_feature_names_out=False)
ftr_trs.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('rbf_kernel', MedianRBFTransformer(),
#                                  ['MonthlyCharges', 'tenure']),
#                                 ('log',
#                                  FunctionTransformer(feature_names_out='one-to-one',
#                                                      func=<ufunc 'log1p'>),
#                                  ['TotalCharges'])],
#                   verbose_feature_names_out=False)

# %%
trs_data = ftr_trs.fit_transform(processed_data)

# %% [raw]
# note to self:
# TransformedTargetRegressor is used when y also needs to be scaled
# we can just proceed normally when y need not be touched ie for classification problems

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
ftr_scl = ColumnTransformer([("scale_data", min_max_scaler, ['rbf_tenure','rbf_MonthlyCharges','TotalCharges'])],remainder='passthrough',verbose_feature_names_out=False)
ftr_scl.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('scale_data', MinMaxScaler(),
#                                  ['rbf_tenure', 'rbf_MonthlyCharges',
#                                   'TotalCharges'])],
#                   verbose_feature_names_out=False)

# %%
scaled_data = ftr_scl.fit_transform(trs_data)

# %%
scaled_data
# Out:
#         rbf_tenure  rbf_MonthlyCharges  TotalCharges  OnlineSecurity  \
# 6661  0.000000e+00        4.670921e-13      0.908413               0
# 4811  7.187782e-28        8.540312e-27      0.581176               0
# 2193  2.187420e-32       2.787151e-106      0.785339               0
# 1904  2.187420e-32        1.226761e-25      0.941844               0
# 6667  4.248354e-18        2.773445e-04      0.726102               0
# ...            ...                 ...           ...             ...
# 4250  6.245366e-51        6.245366e-51      0.969583               1
# 1488  8.939487e-35        8.066314e-17      0.436194               1
# 6303  2.456773e-77        6.137185e-66      0.986842               0
# 2710  8.208500e-02       9.809588e-110      0.681593               0
# 5639  1.061260e-23       1.193560e-108      0.518577               0
#
#       OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# 6661             1                 0            1            1
# ...

# %% [markdown]
# ## building my data pipeline

# %%
from sklearn.pipeline import Pipeline

master_preprocessor = Pipeline(steps=[
    ('step1_process', preprocessing),     
    ('step2_transform', ftr_trs), 
    ('step3_scale', ftr_scl)           
])

master_preprocessor.set_output(transform="pandas")
# Out:
# Pipeline(steps=[('step1_process',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('yes_to_1',
#                                                   FunctionTransformer(feature_names_out='one-to-one',
#                                                                       func=<function true_conv at 0x00000234D4F67B00>),
#                                                   ['OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies', 'Partner',
#                                                    'Dependents', 'PhoneService',
#                                                    'MultipleLines',...
#                                                   MedianRBFTransformer(),
# ...

# %% [raw]
# right now I already performed all of this on my train data so I will use this on my test data leter

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
X=scaled_data.drop(columns=['customerID'])
y=y_train['Churn']

# %%
model = LogisticRegression(solver='liblinear')
scores = cross_val_score(model, X, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.81551561 0.82119205 0.78977273 0.80397727 0.80871212]
# Mean scores: 0.80783395688197

# %% [markdown]
# ## Error analysis

# %%
model.fit(X, y)
coeffs = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_[0]
})
print(coeffs)
# Out:
#                                     Feature  Coefficient
# 0                                rbf_tenure    -0.436087
# 1                        rbf_MonthlyCharges    -0.175913
# 2                              TotalCharges    -4.409521
# 3                            OnlineSecurity    -0.366094
# 4                              OnlineBackup    -0.179721
# 5                          DeviceProtection     0.023351
# 6                               TechSupport    -0.274503
# 7                               StreamingTV     0.314812
# 8                           StreamingMovies     0.386017
# 9                                   Partner    -0.008704
# 10                               Dependents    -0.195379
# 11                             PhoneService    -0.153537
# 12                            MultipleLines     0.343702
# 13                         PaperlessBilling     0.415790
# 14                      InternetService_DSL     0.252573
# ...

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, valid_scores = learning_curve(
model, X, y, train_sizes=np.linspace(0.01, 1.0, 40), cv=5,
scoring="accuracy")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="valid")
plt.show()

# %% [raw]
# the model is underfitting

# %%
from sklearn.model_selection import cross_val_predict

# %%
y_pred = cross_val_predict(model, X, y, cv=kf)
y_proba = cross_val_predict(model, X, y, cv=kf, method="predict_proba")
y_pred_proba = y_proba[:, 1]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()

# %% [raw]
# there are a lot of customers who left but the model predicted them as staying
# maybe I could find a pattern/reason why they left

# %%
err=X.copy()
err['y_pred']=y_pred
err['y']=y
err['y_pred_proba']=y_pred_proba

# %%
err[(err['y_pred']==0) & (err['y']==1) ].hist(bins=50,figsize=(40,20))
plt.show()

# %%
err[(err['y_pred']==1) & (err['y']==1) ].hist(bins=50,figsize=(40,20))
plt.show()

# %%
err[(err['y_pred']==0) & (err['y']==1) ].describe()
# Out:
#          rbf_tenure  rbf_MonthlyCharges  TotalCharges  OnlineSecurity  \
# count  6.520000e+02        6.520000e+02    652.000000      652.000000
# mean   6.799322e-02        5.365690e-02      0.757524        0.277607
# std    2.075074e-01        1.932853e-01      0.188561        0.448162
# min    0.000000e+00       1.374641e-116      0.329480        0.000000
# 25%    2.187420e-32        1.919895e-54      0.638621        0.000000
# 50%    4.248354e-18        1.558350e-25      0.808863        0.000000
# 75%    5.559513e-06        3.668152e-09      0.912825        1.000000
# max    1.000000e+00        9.997500e-01      1.000000        1.000000
#
#        OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# count    652.000000        652.000000   652.000000   652.000000
# mean       0.381902          0.366564     0.277607     0.403374
# std        0.486226          0.482236     0.448162     0.490951
# min        0.000000          0.000000     0.000000     0.000000
# ...

# %%
err[(err['y_pred']==1) & (err['y']==1) ].describe()
# Out:
#          rbf_tenure  rbf_MonthlyCharges  TotalCharges  OnlineSecurity  \
# count  7.500000e+02        7.500000e+02    750.000000      750.000000
# mean   2.037848e-02        1.300640e-01      0.648146        0.052000
# std    1.109568e-01        3.031938e-01      0.159196        0.222175
# min    9.887752e-74        7.246394e-97      0.352462        0.000000
# 25%    8.939487e-35        1.715140e-29      0.487272        0.000000
# 50%    7.187782e-28        2.107205e-14      0.653920        0.000000
# 75%    8.489044e-15        7.764536e-04      0.774149        0.000000
# max    1.000000e+00        1.000000e+00      0.980845        1.000000
#
#        OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# count    750.000000        750.000000    750.00000   750.000000
# mean       0.196000          0.237333      0.07200     0.482667
# std        0.397233          0.425732      0.25866     0.500033
# min        0.000000          0.000000      0.00000     0.000000
# ...

# %%
(err[(err['y_pred']==0) & (err['y']==1) ].mean()-err[(err['y_pred']==1) & (err['y']==1) ].mean()).sort_values()
# Out:
# y_pred                                    -1.000000
# y_pred_proba                              -0.385842
# PaymentMethod_Electronic check            -0.375301
# InternetService_Fiber optic               -0.363800
# Contract_Month-to-month                   -0.246933
# PaperlessBilling                          -0.238965
# SeniorCitizen                             -0.145153
# MultipleLines                             -0.100425
# StreamingMovies                           -0.096896
# StreamingTV                               -0.079292
# rbf_MonthlyCharges                        -0.076407
# PhoneService                              -0.039763
# y                                          0.000000
# gender                                     0.020270
# rbf_tenure                                 0.047615
# Contract_Two year                          0.058282
# PaymentMethod_Mailed check                 0.092658
# TotalCharges                               0.109378
# ...

# %%
print(len(err[(err['y']==1) & (err['InternetService_Fiber optic']==1)])/len(err[(err['y']==1)]))
print(len(err[(err['y']==0) & (err['InternetService_Fiber optic']==1)])/len(err[(err['y']==0)]))
print(len(err[(err['y']==0) & (err['InternetService_Fiber optic']==1)])/len(err[(err['InternetService_Fiber optic']==1)]))
print(len(err[(err['y']==1) & (err['InternetService_Fiber optic']==0)])/len(err[(err['InternetService_Fiber optic']==0)]))
print(len(err[(err['y']==1) & (err['InternetService_Fiber optic']==1)])/len(err[(err['InternetService_Fiber optic']==1)]))
# Out:
# 0.6961483594864479
# 0.34716494845360824
# 0.5798536375376668
# 0.1439675566069618
# 0.42014636246233317

# %% [raw]
# Ok wait so to compare fibre with non fibre
# U can't just say in ppl who churned fibre are more so fibre bad
# Fibre could just be more in general
# In fibre itself if 50% churn that is inherently bad or good either
# The deciding factor is in other connections how is the churn rate looking
# That is what we compare

# %% [raw]
# so churn in fibre optics is defenetly high but the model should see what fibre users are actually leaving

# %%
X1=X.copy()
X1['fib+mon']=((err['Contract_Month-to-month']==1) & (err['InternetService_Fiber optic']==1)).astype(int)

# %%
scores = cross_val_score(model, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.81456954 0.82497635 0.78977273 0.80208333 0.80871212]
# Mean scores: 0.8080228132794358

# %%
model.fit(X1, y)
coeffs = pd.DataFrame({
    "Feature": X1.columns,
    "Coefficient": model.coef_[0]
})
print(coeffs.sort_values(by='Coefficient'))
# Out:
#                                     Feature  Coefficient
# 2                              TotalCharges    -4.429451
# 16                       InternetService_No    -1.037043
# 19                        Contract_Two year    -0.723249
# 0                                rbf_tenure    -0.445416
# 3                            OnlineSecurity    -0.366080
# 6                               TechSupport    -0.273120
# 10                               Dependents    -0.198015
# 1                        rbf_MonthlyCharges    -0.194019
# 4                              OnlineBackup    -0.176042
# 11                             PhoneService    -0.151985
# 9                                   Partner    -0.008885
# 24                                   gender     0.002703
# 21    PaymentMethod_Credit card (automatic)     0.019051
# 5                          DeviceProtection     0.025194
# 20  PaymentMethod_Bank transfer (automatic)     0.027145
# ...

# %% [raw]
# using month to month to figure out what fibre users are leaving did work but it is a 0.001 increase

# %% [raw]
# Instead of trying blindly I want to use corr heatmap

# %%
corr = X1.corr()[['InternetService_Fiber optic']]
plt.figure(figsize=(20,14))
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [raw]
# nothing useful
# going to try some general feature engineering

# %%
X1=X.copy()
X1['disc']=(processed_data['MonthlyCharges']*processed_data['tenure']-processed_data['TotalCharges']).values

# %%
X1['disc'].describe()
# Out:
# count    5282.000000
# mean       -0.453067
# std        67.389155
# min      -373.250000
# 25%       -28.900000
# 50%         0.000000
# 75%        28.000000
# max       370.850000
# Name: disc, dtype: float64

# %%
X1['disc'] = min_max_scaler.fit_transform(X1[['disc']])

# %%
scores = cross_val_score(model, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.80983917 0.82119205 0.78787879 0.80113636 0.80871212]
# Mean scores: 0.8057516986324934

# %% [raw]
# so i tried my best to figure out some new features but that seems to be the end of the road
# now i am going to perform evluation of the model, at the same time try changing the threshold for classification

# %% [raw]
# I will try to fix underfitting by changing the regularisation parameter using grid search

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from scipy.stats import loguniform
from sklearn.metrics import fbeta_score, make_scorer
f2_scorer = make_scorer(fbeta_score, beta=2)
param_distribs = {'C': loguniform(1e-5, 1e2),'penalty': ['l1', 'l2']}
random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_distribs,
    n_iter=50,          
    cv=5,               
    scoring=f2_scorer, 
    random_state=42,
    n_jobs=-1
)
random_search.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(solver='liblinear'),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000234D5183B60>,
#                                         'penalty': ['l1', 'l2']},
#                    random_state=42,
#                    scoring=make_scorer(fbeta_score, response_method='predict', beta=2))

# %%
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")
# Out:
# Best Parameters: {'C': np.float64(0.9047071957568393), 'penalty': 'l2'}
# Best Score: 0.5612746755663811

# %% [raw]
# the value and norm we got is very close to default so there is no point in changing anything

# %% [raw]
# before I leave it here I want to try the class imbalance parameter it fits my case and i did not use it till now

# %%
model1 = LogisticRegression(solver='liblinear',class_weight='balanced')
scores = cross_val_score(model1, X, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.7615894  0.75212867 0.74905303 0.74147727 0.75094697]
# Mean scores: 0.7510390685473467

# %%
y_pred1 = cross_val_predict(model1, X, y, cv=kf)
y_proba1 = cross_val_predict(model1, X, y, cv=kf, method="predict_proba")
y_pred_proba1 = y_proba1[:, 1]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y, y_pred1)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)
param_distribs = {'C': loguniform(1e-5, 1e2),'penalty': ['l1', 'l2']}
random_search = RandomizedSearchCV(
    estimator=model1,
    param_distributions=param_distribs,
    n_iter=50,          
    cv=5,               
    scoring=f2_scorer, 
    random_state=42,
    n_jobs=-1
)
random_search.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=LogisticRegression(class_weight='balanced',
#                                                 solver='liblinear'),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000234E6D6B750>,
#                                         'penalty': ['l1', 'l2']},
#                    random_state=42,
#                    scoring=make_scorer(fbeta_score, response_method='predict', beta=2))

# %%
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")
# Out:
# Best Parameters: {'C': np.float64(1.0126313321124241e-05), 'penalty': 'l2'}
# Best Score: 0.7374371842378957

# %% [markdown]
# ## evaluation

# %% [raw]
# basicaly what i understood is since it's alright we flasly classify a person who is going to stay as churned but we can not have a guy who might churn as safe
# that means we need to have very few false negitives, i.e. we need higher recall rather than precission

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score

# %%
print(precision_score(y, y_pred))
print(recall_score(y, y_pred))
# Out:
# 0.6738544474393531
# 0.5349500713266762

# %% [raw]
# although my accuracy was amazing (almost at 81%) precission and recall show the true picture

# %%
f1_score(y, y_pred) #we can ignore this we don't really care about the f1 score
# Out:
# 0.5964214711729622

# %%
from sklearn.metrics import precision_recall_curve

# %%
precisions, recalls, thresholds = precision_recall_curve(y, y_pred_proba)

# %%
plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
plt.show()

# %%
plt.plot(recalls, precisions, linewidth=2, label="Precision/Recall curve")
plt.xlabel("Recall", fontsize=12)
plt.ylabel("Precision", fontsize=12)
plt.title("Precision–Recall Curve (Logistic Regression)", fontsize=14, fontweight="bold")
plt.show()

# %%
idx_for_80_recall = (recalls <= 0.80).argmax()
threshold_for_80_recall = thresholds[idx_for_80_recall]
threshold_for_80_recall
# Out:
# np.float64(0.26752795046604316)

# %%
precisions[idx_for_80_recall]
# Out:
# np.float64(0.5199443413729128)

# %%
y_pred_new=(y_pred_proba>threshold_for_80_recall).astype(int)

# %%
from sklearn.metrics import accuracy_score
new_accuracy = accuracy_score(y, y_pred_new)
print(f"Overall CV Accuracy with custom threshold: {new_accuracy:.4f}")
# Out:
# Overall CV Accuracy with custom threshold: 0.7507

# %%
cm_new = confusion_matrix(y, y_pred_new)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_new)
disp.plot(cmap="Blues")
plt.show()

# %%
print(precision_score(y, y_pred_new))
print(recall_score(y, y_pred_new))
# Out:
# 0.5197215777262181
# 0.7988587731811697

# %% [raw]
# precission and recall of model with class_weights=balanced

# %%
print(precision_score(y, y_pred1))
print(recall_score(y, y_pred1))
# Out:
# 0.5201482167670217
# 0.8009985734664765

# %% [raw]
# this is very interesting to look at because i basically achieved the same results as model with class weights using a model without the hyper parameter simply by changing the threshold IN LOGISTIC REGRESSION

# %% [markdown]
# ## Advanced models

# %% [raw]
# now that I have built a baseline let's focus on building more advanced models
# the plan is we will test  tree vs random forest vs boosting techniques

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [raw]
# I am planning on finding the optimal parameters for this and everything so first no parameters at all to see what it does

# %%
tree_clf = DecisionTreeClassifier(random_state=42)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
scores = cross_val_score(tree_clf, X, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.7218543  0.72280038 0.74147727 0.73390152 0.72537879]
# Mean scores: 0.729082451764571

# %%
y_predt = cross_val_predict(tree_clf, X, y, cv=kf)
y_probat = cross_val_predict(tree_clf, X, y, cv=kf, method="predict_proba")
y_pred_probat = y_probat[:, 1]

# %%
print(precision_score(y, y_predt))
print(recall_score(y, y_predt))
# Out:
# 0.49014276002719237
# 0.514265335235378

# %%
train_sizes, train_scores, valid_scores = learning_curve(
tree_clf, X, y, train_sizes=np.linspace(0.01, 1.0, 40), cv=5,
scoring="accuracy")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="valid")
plt.show()

# %% [raw]
# ok I got exactly what I expected
# the model is clearly overfitting the data
# there are two main things I can do firstly I can try fixing the parameters if that doesn't work visualising the data using pca would prove helpful

# %%
param_distribs = {"max_depth": randint(2, 20), "min_samples_leaf": randint(1, 20) }
random_search = RandomizedSearchCV(
    estimator=tree_clf,
    param_distributions=param_distribs,
    n_iter=100,          
    cv=5,               
    scoring='accuracy', 
    random_state=42,
    n_jobs=-1
)
random_search.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000234D7D5BA10>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000234DDC55A90>},
#                    random_state=42, scoring='accuracy')

# %%
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")
# Out:
# Best Parameters: {'max_depth': 3, 'min_samples_leaf': 1}
# Best Score: 0.7907958487428686

# %%
tree_clf_n = DecisionTreeClassifier(random_state=42,max_depth=3,min_samples_leaf=1)
tree_clf_n.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
train_sizes, train_scores, valid_scores = learning_curve(
tree_clf_n, X, y, train_sizes=np.linspace(0.01, 1.0, 40), cv=5,
scoring="accuracy")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="valid")
plt.show()

# %%
y_predtn = cross_val_predict(tree_clf_n, X, y, cv=kf)
y_probatn = cross_val_predict(tree_clf_n, X, y, cv=kf, method="predict_proba")
y_pred_probatn = y_probatn[:, 1]

# %%
print(precision_score(y, y_predtn))
print(recall_score(y, y_predtn))
# Out:
# 0.6873385012919897
# 0.37945791726105566

# %% [raw]
# I wanted to test the tree with f2 scorer but realised it will bring no change cuz the tree is focused on entropy and gini and not my scoring function

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap='coolwarm', alpha=0.7)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization")
plt.colorbar(label="Class")
plt.show()

# %% [raw]
# right now it almost seems impossible to seperate properly
# I also want to test lda and t-sne to see if the seperation is in a higher dimension

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_lda = lda.fit_transform(X, y)
plt.figure(figsize=(8,6))
plt.hist(X_lda[y==0], bins=30, alpha=0.7, label="Class 0", color="green")
plt.hist(X_lda[y==1], bins=30, alpha=0.7, label="Class 1", color="red")
plt.xlabel("Linear Discriminant 1")
plt.ylabel("Frequency")
plt.title("LDA Visualization (Binary Classes)")
plt.legend()
plt.show()

# %% [raw]
# so yeah no matter what I do I can't fully seperate both the classes
# i will only see performance increse with non liner models like forests and boostings

# %%
random_search.fit(X_lda, y)
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")
# Out:
# Best Parameters: {'max_depth': 3, 'min_samples_leaf': 15}
# Best Score: 0.8051829792723832

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
X_tsne = tsne.fit_transform(X)
plt.figure(figsize=(8,6))
plt.scatter(X_tsne[:,0], X_tsne[:,1], c=y, cmap='coolwarm', alpha=0.7)
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.title("t-SNE Visualization")
plt.colorbar(label="Class")
plt.show()

# %% [markdown]
# ## Let's try forests, ensambles and bosstings

# %% [raw]
# ok see the thing is the relation between the data is linear so linear regression is doing pretty good but there is no clear signal indicating the difference
# so no matter what forests and boostings should defently help

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %% [raw]
# param_grid = {
#     "n_estimators": [100, 200, 300, 400, 500],
#     "max_leaf_nodes": [8, 16, 32, 64]
# }

# %%
rnd_clf = RandomForestClassifier(n_jobs=-1, random_state=42)
param_grid = {
    "n_estimators": [300, 500],
    "max_depth": [3, 5, 8], 
    "min_samples_leaf": [20, 50, 100], 
    "max_features": ["sqrt", 0.5] 
}
grid_search = GridSearchCV(
    rnd_clf,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 8], 'max_features': ['sqrt', 0.5],
#                          'min_samples_leaf': [20, 50, 100],
#                          'n_estimators': [300, 500]},
#              scoring='accuracy')

# %%
print("Best parameters:", grid_search.best_params_)
print("Best estimator:", grid_search.best_score_)
# Out:
# Best parameters: {'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'n_estimators': 500}
# Best estimator: 0.8012066024483243

# %%
rnd_clf_n = RandomForestClassifier(n_jobs=-1, random_state=42,max_leaf_nodes=64,n_estimators=300)
rnd_clf_n.fit(X,y)
# Out:
# RandomForestClassifier(max_leaf_nodes=64, n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
y_predr = cross_val_predict(rnd_clf_n, X, y, cv=kf)
y_probar = cross_val_predict(rnd_clf_n, X, y, cv=kf, method="predict_proba")
y_pred_probar = y_probar[:, 1]

# %%
print(precision_score(y, y_predr))
print(recall_score(y, y_predr))
# Out:
# 0.666023166023166
# 0.4921540656205421

# %%
train_sizes, train_scores, valid_scores = learning_curve(
rnd_clf_n, X, y, train_sizes=np.linspace(0.01, 1.0, 40), cv=5,
scoring="accuracy")
train_errors = -train_scores.mean(axis=1)
valid_errors = -valid_scores.mean(axis=1)
plt.plot(train_sizes, train_errors, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, valid_errors, "b-", linewidth=3, label="valid")
plt.show()

# %% [raw]
# ok this was completely unexpected
# there is actually high variance here
# so the model is overfitting
# even after trying grid search and for the optimal parametres
# so fixinig this might be the solution i need
# i tried changing the hyperparametrs more but it did not work

# %% [raw]
# doing a quick test that this the data set is linear by doing a simple svm confirmation

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
svm_clf = LinearSVC(C=1, random_state=42)
scores = cross_val_score(svm_clf, X, y, cv=5, scoring="accuracy")
print("Accuracy scores for each fold:", scores)
print("Mean accuracy:", scores.mean())
# Out:
# Accuracy scores for each fold: [0.80321665 0.8230842  0.80587121 0.78030303 0.80587121]
# Mean accuracy: 0.8036692612023737

# %%
from sklearn.inspection import permutation_importance
perm_importance = permutation_importance(
    rnd_clf_n, X, y, n_repeats=10, random_state=42, scoring='recall')

# %%
feature_names = X.columns
perm_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': perm_importance.importances_mean,
    'Std_Dev': perm_importance.importances_std
}).sort_values(by='Importance', ascending=False)

# %%
plt.figure(figsize=(10, 6))
plt.barh(perm_importance_df['Feature'], perm_importance_df['Importance'], xerr=perm_importance_df['Std_Dev'], color='lightcoral')
plt.gca().invert_yaxis()
plt.title("Permutation Feature Importance (Impact on Recall)")
plt.xlabel("Decrease in Recall Score")
plt.show()

# %%
X1=X.copy()
X1['fib+mon']=((err['Contract_Month-to-month']==1) & (err['InternetService_Fiber optic']==1)).astype(int)

# %%
scores = cross_val_score(rnd_clf_n, X1, y, cv=5, scoring="accuracy")
print("Accuracy scores for each fold:", scores)
print("Mean accuracy:", scores.mean())
# Out:
# Accuracy scores for each fold: [0.79943236 0.82497635 0.78598485 0.78219697 0.80113636]
# Mean accuracy: 0.798745377139417

# %% [raw]
# that actually overfit the data
# it makes sense for two reasons
# iam ruining the randomness by putting two of the same things in the hat
# i am also just doing what it is already doing well

# %% [raw]
# let's see if fibre optic has any relation to total charges

# %%
X.groupby('InternetService_Fiber optic')['TotalCharges'].mean()
# Out:
# InternetService_Fiber optic
# 0.0    0.717374
# 1.0    0.824051
# Name: TotalCharges, dtype: float64

# %% [raw]
# it sure does
# let's try the simplest feature construction technique which is to multiply

# %%
X1['hig_fib']=X1['fib+mon']*X1['TotalCharges']

# %%
scores = cross_val_score(model, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.81456954 0.82497635 0.78977273 0.80208333 0.80871212]
# Mean scores: 0.8080228132794358

# %% [raw]
# ok that made it worse

# %%
X1.drop('hig_fib', axis=1, inplace=True)

# %%
X1.drop('fib+mon', axis=1, inplace=True)

# %% [raw]
# ok lesson learned-
# feature importances are biased towards highly unique values
# led me to beleive total charges was super important
# did not help

# %% [raw]
# ok now I have two things to try
# 1) dropping total charges
# so why drop this it is useful right
# well actually the data total charges has is basically monthly charges*tenure
# so it's a redundancy
# you might think wait why does area actually be helpful it is lenght * breadth but total charges not help
# length and breadth are both positive
# but monthly charges and tenure are not
# what i mean is more monthly charges means churn but more tenure means no churn
# 2) the second thing is I still wanna try the fibre optic thing but this time with monthly charges
# the reason is totacl charges is unreliabale ppl who stayed long also have huge totacl charges

# %%
X.groupby('InternetService_Fiber optic')['rbf_MonthlyCharges'].mean()
# Out:
# InternetService_Fiber optic
# 0.0    0.051288
# 1.0    0.087955
# Name: rbf_MonthlyCharges, dtype: float64

# %%
X1.drop('TotalCharges', axis=1, inplace=True)

# %%
scores = cross_val_score(model, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.80889309 0.79470199 0.76704545 0.78598485 0.79640152]
# Mean scores: 0.7906053797196182

# %%
scores = cross_val_score(rnd_clf_n, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.80794702 0.80321665 0.76609848 0.78977273 0.78693182]
# Mean scores: 0.79079334021387

# %% [raw]
# the accuracy dropping by only 1 or 2 % is a win cuz the model is more robust it shows that total charges is redundant
# if I wanna win kaggle i would keep it but to build a robust model i would drop it that is because the model is only getting an accuracy gain cuz it is overfitting the data and a real model should't do that

# %% [raw]
# now for my second test

# %%
median_cost = X1['rbf_MonthlyCharges'].median()
X1['is_expensive_fiber'] = ((X1['InternetService_Fiber optic'] == 1.0) & (X1['rbf_MonthlyCharges'] > median_cost)).astype(int)

# %%
scores = cross_val_score(model, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.80605487 0.80227058 0.76325758 0.7907197  0.79450758]
# Mean scores: 0.7913620595739801

# %%
scores = cross_val_score(rnd_clf_n, X1, y, cv=kf, scoring="accuracy")
print("scores:", scores)
print("Mean scores:", scores.mean())
# Out:
# scores: [0.80700095 0.8051088  0.76704545 0.78977273 0.78598485]
# Mean scores: 0.7909825549726213

# %%
X1.drop('is_expensive_fiber', axis=1, inplace=True)

# %%
rnd_clf_n.fit(X1,y)
# Out:
# RandomForestClassifier(max_leaf_nodes=64, n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
perm_importance = permutation_importance(
    rnd_clf_n, X1, y, n_repeats=10, random_state=42, scoring='recall')

# %%
feature_names = X1.columns
perm_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': perm_importance.importances_mean,
    'Std_Dev': perm_importance.importances_std
}).sort_values(by='Importance', ascending=False)

# %%
plt.figure(figsize=(10, 6))
plt.barh(perm_importance_df['Feature'], perm_importance_df['Importance'], xerr=perm_importance_df['Std_Dev'], color='lightcoral')
plt.gca().invert_yaxis()
plt.title("Permutation Feature Importance (Impact on Recall)")
plt.xlabel("Decrease in Recall Score")
plt.show()

# %% [markdown]
# ## Wrapping things up and CONCLUSIONS

# %% [raw]
# so basically I am going to wrap this up I got everything I need

# %% [markdown]
# ### the conclusions are-
# the data is linear that is why my best performin model was linear regression <br>
# the useful thing I got is I should drop total charges <br>
# my application is to predict ppl who will leave rather than just have high accuracy<br>
# hence i fine tuned my model for that <br>
# i traded precission for more recall <br>
# the analysis of the data is that there is high overlap between both the classes and there isn't any strong feature tat reveals the full information

# %% [raw]
# If i had to present a story on what is happening
# i would say ppl who opted for monthly subscription are not staying around and fibre optic needs to be studied more

# %% [raw]
# so the final pipeline would be my data processer(where i remove the total charges) + logistic regression model where class weight is set to balanced
# it got me the highest recall

# %% [raw]
# ok two steps rewrite the preprocessing column transformer
# then build my pipeline again using the new column transformer

# %%
preprocessing = ColumnTransformer([("yes_to_1", yes_no_transformer, bin_at),("ohe", enc, ohe_at),('drop','drop',['TotalCharges']),('ohe_gen',gender_transformer,['gender'])],remainder='passthrough',verbose_feature_names_out=False)
preprocessing.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('yes_to_1',
#                                  FunctionTransformer(feature_names_out='one-to-one',
#                                                      func=<function true_conv at 0x00000234D4F67B00>),
#                                  ['OnlineSecurity', 'OnlineBackup',
#                                   'DeviceProtection', 'TechSupport',
#                                   'StreamingTV', 'StreamingMovies', 'Partner',
#                                   'Dependents', 'PhoneService', 'MultipleLines',
#                                   'PaperlessBilling']),
#                                 ('ohe', OneHotEncoder(sparse_output=False),
#                                  ['InternetService', 'Contract',
#                                   'PaymentMethod']),
#                                 ('drop', 'drop', ['TotalCharges']),
#                                 ('ohe_gen',
# ...

# %%
rb_col=['MonthlyCharges','tenure']
ftr_trs = ColumnTransformer([("rbf_kernel", MedianRBFTransformer(gamma=0.1), rb_col)],remainder='passthrough',verbose_feature_names_out=False)
ftr_trs.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('rbf_kernel', MedianRBFTransformer(),
#                                  ['MonthlyCharges', 'tenure'])],
#                   verbose_feature_names_out=False)

# %%
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
ftr_scl = ColumnTransformer([("scale_data", min_max_scaler, ['rbf_tenure','rbf_MonthlyCharges',])],remainder='passthrough',verbose_feature_names_out=False)
ftr_scl.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('scale_data', MinMaxScaler(),
#                                  ['rbf_tenure', 'rbf_MonthlyCharges'])],
#                   verbose_feature_names_out=False)

# %%
master_preprocessor = Pipeline(steps=[
    ('step1_process', preprocessing),     
    ('step2_transform', ftr_trs), 
    ('step3_scale', ftr_scl)           
])
master_preprocessor.set_output(transform="pandas")
# Out:
# Pipeline(steps=[('step1_process',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('yes_to_1',
#                                                   FunctionTransformer(feature_names_out='one-to-one',
#                                                                       func=<function true_conv at 0x00000234D4F67B00>),
#                                                   ['OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies', 'Partner',
#                                                    'Dependents', 'PhoneService',
#                                                    'MultipleLines',...
#                                    verbose_feature_names_out=False)),
# ...

# %% [raw]
# need to check if my pipeline is working

# %%
testing=X_train.copy()

# %%
training_transformed = master_preprocessor.fit_transform(training)

# %%
training_transformed
# Out:
#         rbf_tenure  rbf_MonthlyCharges  OnlineSecurity  OnlineBackup  \
# 6661  0.000000e+00        4.670921e-13               0             1
# 4811  7.187782e-28        8.540312e-27               0             0
# 2193  2.187420e-32       2.787151e-106               0             0
# 1904  2.187420e-32        1.226761e-25               0             1
# 6667  4.248354e-18        2.773445e-04               0             0
# ...            ...                 ...             ...           ...
# 4250  6.245366e-51        6.245366e-51               1             1
# 1488  8.939487e-35        8.066314e-17               1             0
# 6303  2.456773e-77        6.137185e-66               0             1
# 2710  8.208500e-02       9.809588e-110               0             0
# 5639  1.061260e-23       1.193560e-108               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Partner  \
# ...

# %% [raw]
# ok yipeee it worked

# %%
model1.fit(X1,y)
# Out:
# LogisticRegression(class_weight='balanced', solver='liblinear')

# %%
from sklearn.base import ClassifierMixin

# %% [raw]
# I am writing my own custom predicter cuz I am doing this thing where I strip customer id predict then append it back
# it has 'self.is_fitted_ = True' cuz my model is already trained and i am tricking scikit learn saying i fit my transformer

# %%
class PredictAndAppendID(BaseEstimator, ClassifierMixin):
    def __init__(self, model, id_col='customerID'):
        self.model = model
        self.id_col = id_col
        self.is_fitted_ = True
        
    def fit(self, X, y=None):
        X_clean = X.drop(columns=[self.id_col])
        self.model.fit(X_clean, y)
        return self
        
    def predict(self, X):
        saved_ids = X[self.id_col].reset_index(drop=True)
        
        X_clean = X.drop(columns=[self.id_col])
        
        preds = self.model.predict(X_clean)
        
        return pd.DataFrame({
            self.id_col: saved_ids,
            'prediction': preds
        })

# %%
wrapper = PredictAndAppendID(model=model1, id_col='customerID')

final_pipeline = Pipeline(steps=[
    ('process', master_preprocessor),     
    ('predict', wrapper)            
])

# %%
final_results = final_pipeline.predict(testing)
print(final_results)
# Out:
#       customerID  prediction
# 0     3704-IEAXF           0
# 1     5175-AOBHI           1
# 2     6922-NCEDI           0
# 3     3143-ILDAL           1
# 4     0872-NXJYS           1
# ...          ...         ...
# 5277  0565-JUPYD           0
# 5278  8695-WDYEA           0
# 5279  6308-CQRBU           0
# 5280  3594-BDSOA           0
# 5281  6490-FGZAT           0
#
# [5282 rows x 2 columns]

# %% [raw]
# now that this is working prefectly I am going to get the final results on my test data

# %%
y_test['Churn']=(y_test['Churn']=='Yes').astype(int)

# %%
y_test
# Out:
#       Churn  customerID
# 5909      0  5343-SGUBI
# 3670      0  5442-BXVND
# 6220      0  6434-TTGJP
# 5905      0  1628-BIZYP
# 6435      0  0298-XACET
# ...     ...         ...
# 476       0  3780-DDGSE
# 1607      1  4154-AQUGT
# 6808      0  1116-DXXDF
# 2962      1  3237-AJGEH
# 3955      0  6704-UTUKK
#
# [1761 rows x 2 columns]

# %%
final_results = final_pipeline.predict(X_test)
print(final_results)
# Out:
#       customerID  prediction
# 0     5343-SGUBI           0
# 1     5442-BXVND           0
# 2     6434-TTGJP           0
# 3     1628-BIZYP           1
# 4     0298-XACET           0
# ...          ...         ...
# 1756  3780-DDGSE           1
# 1757  4154-AQUGT           1
# 1758  1116-DXXDF           0
# 1759  3237-AJGEH           1
# 1760  6704-UTUKK           1
#
# [1761 rows x 2 columns]

# %%
print(precision_score(y_test['Churn'], final_results['prediction']))
print(recall_score(y_test['Churn'], final_results['prediction']))
# Out:
# 0.489247311827957
# 0.7794432548179872

# %% [markdown]
# ## so my model has more than 75% reccall rate with nearly 50% precission

# %% [markdown]
# # The END
